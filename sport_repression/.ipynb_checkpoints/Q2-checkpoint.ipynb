# %% [markdown]
# First, we need to import the required data.

# %%
import pandas as pd

# %%
data = pd.read_csv('data/main_data.tab', sep= '\t')

# %% [markdown]
# We see that there are a lot of NaN values, so we need to get rid of them.

# %%
data.dropna()
# Out:
#                       muni     id          prov  id_prov  \
# 11675   general pueyrredon   44.0  buenos aires      1.0
# 11676   general pueyrredon   44.0  buenos aires      1.0
# 11677   general pueyrredon   44.0  buenos aires      1.0
# 11678   general pueyrredon   44.0  buenos aires      1.0
# 11679   general pueyrredon   44.0  buenos aires      1.0
# ...                    ...    ...           ...      ...
# 119431             rosario  446.0      santa fe     21.0
# 119432             rosario  446.0      santa fe     21.0
# 119433             rosario  446.0      santa fe     21.0
# 119434             rosario  446.0      santa fe     21.0
# 119435             rosario  446.0      santa fe     21.0
#
#                                muniprov  repression  lnrepression  \
# 11675   general pueyrredon buenos aires         0.0           0.0
# 11676   general pueyrredon buenos aires         0.0           0.0
# 11677   general pueyrredon buenos aires         0.0           0.0
# ...

# %%
data
# Out:
#                  muni     id          prov  id_prov  \
# 0       adolfo alsina    1.0  buenos aires      1.0
# 1       adolfo alsina    1.0  buenos aires      1.0
# 2       adolfo alsina    1.0  buenos aires      1.0
# 3       adolfo alsina    1.0  buenos aires      1.0
# 4       adolfo alsina    1.0  buenos aires      1.0
# ...               ...    ...           ...      ...
# 133727    yerba buena  499.0       tucuman     24.0
# 133728    yerba buena  499.0       tucuman     24.0
# 133729    yerba buena  499.0       tucuman     24.0
# 133730    yerba buena  499.0       tucuman     24.0
# 133731    yerba buena  499.0       tucuman     24.0
#
#                           muniprov  repression  lnrepression  dumrepression  \
# 0       adolfo alsina buenos aires         0.0           0.0            0.0
# 1       adolfo alsina buenos aires         0.0           0.0            0.0
# 2       adolfo alsina buenos aires         0.0           0.0            0.0
# ...

# %%
data['time2'].max()
# Out:
# 1.3689

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
import numpy as np
from plotnine import *
import seaborn as sns
import scipy.stats.stats as stats

# %matplotlib inline

# %%
model1 = smf.ols("lnrepression ~ hostcitytime + hostcitytime2 + hostcity + time + time2", data = data)

# %%
m1 = model1.fit(cov_type='hc1')

# %%
m1.summary()
# Out:
# c:\users\mernick\appdata\local\programs\python\python39\lib\site-packages\statsmodels\base\model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 5, but rank is 3
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           lnrepression   R-squared:                       0.054
# Model:                            OLS   Adj. R-squared:                  0.035
# Method:                 Least Squares   F-statistic:                    0.6999
# Date:                Mon, 05 Dec 2022   Prob (F-statistic):              0.554
# Time:                        17:23:10   Log-Likelihood:                 94.155
# No. Observations:                 100   AIC:                            -182.3
# Df Residuals:                      97   BIC:                            -174.5
# Df Model:                           2
# Covariance Type:                  hc1
# ...

# %%
model2 = smf.ols("lnrepression ~ hostcitytime + hostcitytime2 + hostcity + time + time2 + lnpop_1970 + vote_frejuli + literacy_avg + lnrebact1974 + lnrepression70_77", data = data)
m2 = model2.fit(cov_type='hc1')
m2.summary()
# Out:
# c:\users\mernick\appdata\local\programs\python\python39\lib\site-packages\statsmodels\base\model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 10, but rank is 6
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           lnrepression   R-squared:                       0.115
# Model:                            OLS   Adj. R-squared:                  0.068
# Method:                 Least Squares   F-statistic:                    0.3903
# Date:                Mon, 05 Dec 2022   Prob (F-statistic):              0.884
# Time:                        17:23:10   Log-Likelihood:                 97.501
# No. Observations:                 100   AIC:                            -183.0
# Df Residuals:                      94   BIC:                            -167.4
# Df Model:                           5
# Covariance Type:                  hc1
# ...

# %%
model3 = smf.ols("lnrepression ~ hostcitytime + hostcitytime2 + hostcity + time + time2 + lnpop_1970 + vote_frejuli + literacy_avg + lnrebact1974 + lnrepression70_77 + zone2 + zone3 + zone4 + zone5", data = data)
m3 = model3.fit()
m3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           lnrepression   R-squared:                       0.063
# Model:                            OLS   Adj. R-squared:                  0.063
# Method:                 Least Squares   F-statistic:                     271.8
# Date:                Mon, 05 Dec 2022   Prob (F-statistic):               0.00
# Time:                        00:04:55   Log-Likelihood:                 86946.
# No. Observations:               56394   AIC:                        -1.739e+05
# Df Residuals:                   56379   BIC:                        -1.737e+05
# Df Model:                          14
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...
